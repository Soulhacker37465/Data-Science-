# %% [markdown]
# ## Stirng &  String method

# %%
name =  "ga urav"

# %%
name.capitalize()
# Out:
# 'Gaurav'

# %%
name.upper()
# Out:
# 'GAURAV'

# %%
name.count("a")
# Out:
# 2

# %%
name.strip()
# Out:
# 'Gaurav'

# %%
name.split()
# Out:
# ['Gaurav']
