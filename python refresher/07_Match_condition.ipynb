# %%
code = 400

# %%
match code:
    case 200:
        print("Response OK")
        print("Good Job!")
    case 400:
        print("Bad Response")
    case 404:
        print("Not found?")
    case _:
        print("Nothing Matched")
print("Session is end")
# Out:
# Bad Response
# Session is end
