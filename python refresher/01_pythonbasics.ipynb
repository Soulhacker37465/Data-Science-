# %%
a = 5

# %%
b = 6

# %%
a + b
# Out:
# 11

# %% [raw]
# str = "gaurav"

# %%
print("Hello world")
# Out:
# Hello world

# %%
  print(type(a))
# Out:
# <class 'int'>

# %%
a = "33678"

# %%
b = "36384"

# %%
int(a) + int(b) # type casting
# Out:
# 70062
