# %%
import json

# %%
obj = {"name" : "Alice", "Company" : "INB", "salary" : "20000"}
json.dumps(obj)
# Out:
# '{"name": "Alice", "Company": "INB", "salary": "20000"}'

# %%
d = json.loads('{"name": "Alice", "Company": "INB", "salary": "20000"}')

# %%
type(d)
# Out:
# dict

# %%
file = open("data.json", "w")

# %%
json.dump(obj, file)

# %%
file.close()
